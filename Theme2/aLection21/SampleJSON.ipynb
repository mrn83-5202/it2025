# %%
myJson = {
  "name": "John Doe",
  "age": 30,
  "isStudent": False,
  "email": "johndoe@example.com",
  "courses": ["Mathematics", "Physics", "Computer Science"],
  "address": {
    "street": "123 Main St",
    "city": "New York",
    "zipcode": "10001"
  }
}
