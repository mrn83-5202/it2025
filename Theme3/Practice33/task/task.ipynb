# %% [markdown]
# ### **Практичне завдання для слухачів**
#
# #### **Мета завдання:**
# Розробити, навчити та оцінити моделі регресії та класифікації на індивідуальних наборах даних (`variant_N.csv`).
#
# ---
#
# ### **Завдання 1: Регресійний аналіз (Linear Regression, Random Forest Regressor)**
# 📌 **Вхідні дані**: ваш унікальний набір (`variant_N.csv`) містить числові та категоріальні ознаки, а також цільову змінну `target`, яку потрібно прогнозувати.
#
# 1. Завантажити свій набір даних та виконати **передобробку**:
#    - Видалити пропущені значення.
#    - Закодувати категоріальні ознаки.
#    - Масштабувати числові дані (якщо потрібно).
# 2. Побудувати модель **лінійної регресії**, навчити її та оцінити якість за метриками MAE та MSE.
# 3. Побудувати модель **Random Forest Regressor** та порівняти її результати з лінійною регресією.
# 4. Визначити, яка модель дає кращі результати та пояснити чому.
#
# **Очікуваний результат:**
# - Код для підготовки даних та навчання моделей.
# - Порівняння показників якості MAE, MSE, r²-score.
# - Аналіз переваг/недоліків кожної моделі.
#
# ---
#
# ### **Завдання 2: Класифікація (Logistic Regression, Random Forest Classifier)**
# 📌 **Вхідні дані**: ваш набір (`variant_N.csv`) містить категоріальні та числові ознаки, а також цільову змінну `target`, яка є класовою (0 або 1).
#
# 1. Виконати **передобробку даних** (аналогічно до регресії).
# 2. Побудувати модель **логістичної регресії**, навчити її та оцінити якість за метрикою `accuracy_score`.
# 3. Побудувати модель **Random Forest Classifier**, навчити її та порівняти результати з логістичною регресією.
# 4. Використати `classification_report`, щоб оцінити точність, повноту та F1-міру для кожного класу.
# 5. Порівняти результати обох моделей та пояснити, яка модель краще підходить для даних.
#
# **Очікуваний результат:**
# - Код для підготовки даних та навчання моделей.
# - Значення `accuracy_score`, `precision`, `recall`, `F1-score`.
# - Аналіз роботи моделей та висновки.
#
# ---
#
# ### **Завдання 3 (Додаткове, для просунутих слухачів): Вибір найкращої моделі**
# 📌 **Мета**: Оптимізувати обрану модель шляхом налаштування гіперпараметрів.
#
# 1. Використати **GridSearchCV або RandomizedSearchCV** для пошуку найкращих параметрів для `Random Forest Regressor` або `Random Forest Classifier`.
# 2. Оцінити, як змінилися результати після оптимізації.
# 3. Визначити найкращі параметри для моделі.
#
# **Очікуваний результат:**
# - Код для пошуку оптимальних параметрів.
# - Порівняння результатів до і після оптимізації.
# - Висновки щодо покращення моделі.
#
# ---
#
# 📌 **Фінальна мета**: навчитися ефективно будувати моделі регресії та класифікації, порівнювати їх та робити обґрунтовані висновки щодо їх якості. 🚀
