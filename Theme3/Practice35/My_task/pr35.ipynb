# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("russia_losses_equipment.csv", 
                 parse_dates=["date"], 
                 index_col="date")

# %%
df.head()
# Out:
#              day  aircraft  helicopter   tank    APC  field artillery   MRL  \
# date
# 2025-03-09  1110       370         331  10274  21360            24206  1310
# 2025-03-08  1109       370         331  10268  21346            24148  1307
# 2025-03-07  1108       370         331  10264  21334            24124  1306
# 2025-03-06  1107       370         331  10261  21311            24108  1306
# 2025-03-05  1106       370         331  10256  21304            24087  1306
#
#             military auto  fuel tank  drone  naval ship  \
# date
# 2025-03-09            NaN        NaN  28362          28
# 2025-03-08            NaN        NaN  28172          28
# 2025-03-07            NaN        NaN  28024          28
# 2025-03-06            NaN        NaN  27929          28
# 2025-03-05            NaN        NaN  27849          28
#
#             anti-aircraft warfare  special equipment  mobile SRBM system  \
# date
# 2025-03-09                   1101             3773.0                 NaN
# 2025-03-08                   1099             3772.0                 NaN
# 2025-03-07                   1096             3769.0                 NaN
# 2025-03-06                   1096             3769.0                 NaN
# 2025-03-05                   1094             3769.0                 NaN
#
#            greatest losses direction  vehicles and fuel tanks  \
# date
# 2025-03-09                       NaN                  39933.0
# 2025-03-08                       NaN                  39791.0
# 2025-03-07                       NaN                  39678.0
# 2025-03-06                       NaN                  39606.0
# 2025-03-05                       NaN                  39512.0
#
#             cruise missiles  submarines
# date
# 2025-03-09           3120.0         1.0
# 2025-03-08           3120.0         1.0
# 2025-03-07           3085.0         1.0
# 2025-03-06           3085.0         1.0
# 2025-03-05           3085.0         1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1109 entries, 2025-03-09 to 2022-02-25
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   day                        1109 non-null   int64
#  1   aircraft                   1109 non-null   int64
#  2   helicopter                 1109 non-null   int64
#  3   tank                       1109 non-null   int64
#  4   APC                        1109 non-null   int64
#  5   field artillery            1109 non-null   int64
#  6   MRL                        1109 non-null   int64
#  7   military auto              65 non-null     float64
#  8   fuel tank                  65 non-null     float64
#  9   drone                      1109 non-null   int64
#  10  naval ship                 1109 non-null   int64
#  11  anti-aircraft warfare      1109 non-null   int64
#  12  special equipment          1090 non-null   float64
#  13  mobile SRBM system         36 non-null     float64
#  14  greatest losses direction  203 non-null    object
#  15  vehicles and fuel tanks    1044 non-null   float64
#  16  cruise missiles            1044 non-null   float64
#  17  submarines                 543 non-null    float64
# dtypes: float64(7), int64(10), object(1)
# memory usage: 164.6+ KB

# %%
df.describe()
# Out:
#                day     aircraft   helicopter          tank           APC  \
# count  1109.000000  1109.000000  1109.000000   1109.000000   1109.000000
# mean    556.000000   302.796213   281.954914   5112.980162  10146.060415
# std     320.285029    67.475573    64.417241   2879.605432   5665.793068
# min       2.000000    10.000000     7.000000     80.000000    516.000000
# 25%     279.000000   280.000000   261.000000   2911.000000   5866.000000
# 50%     556.000000   315.000000   316.000000   4471.000000   8637.000000
# 75%     833.000000   357.000000   326.000000   7806.000000  15036.000000
# max    1110.000000   370.000000   331.000000  10274.000000  21360.000000
#
#        field artillery          MRL  military auto  fuel tank         drone  \
# count      1109.000000  1109.000000      65.000000  65.000000   1109.000000
# mean       8110.674482   734.900812    1047.507692  69.323077   7081.280433
# std        7331.229748   382.581077     466.162060   7.545917   7102.179229
# min          49.000000     4.000000     100.000000  60.000000      0.000000
# 25%        1901.000000   395.000000     600.000000  60.000000   1555.000000
# 50%        5560.000000   736.000000    1178.000000  73.000000   4433.000000
# 75%       13385.000000  1092.000000    1437.000000  76.000000  10805.000000
# max       24206.000000  1310.000000    1701.000000  76.000000  28362.000000
#
#         naval ship  anti-aircraft warfare  special equipment  \
# count  1109.000000            1109.000000        1090.000000
# mean     20.338142             515.275924        1311.750459
# std       6.370637             337.083908        1286.030293
# min       2.000000               0.000000          10.000000
# 25%      16.000000             209.000000         170.250000
# 50%      18.000000             501.000000         879.000000
# 75%      27.000000             830.000000        2263.500000
# max      28.000000            1101.000000        3773.000000
#
#        mobile SRBM system  vehicles and fuel tanks  cruise missiles  \
# count           36.000000              1044.000000      1044.000000
# mean             3.944444             12854.297893      1498.744253
# std              0.333333             10189.086633       926.258526
# min              2.000000              1796.000000        84.000000
# 25%              4.000000              4875.250000       749.000000
# 50%              4.000000              8971.000000      1530.000000
# 75%              4.000000             19186.750000      2299.000000
# max              4.000000             39933.000000      3120.000000
#
#        submarines
# count       543.0
# mean          1.0
# std           0.0
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           1.0
# max           1.0

# %%
df1 = df[["APC"]]

# %%
df1.isnull().sum()
# Out:
# APC    0
# dtype: int64

# %%
plt.figure(figsize=(12,5))
plt.plot(df1["APC"], label = "Втрачено ББМ")
plt.plot(df["tank"], label = "Втрачено танків")
plt.plot(df["aircraft"], label = "Втрачено літаків")
plt.legend()
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
train_size = int(len(df1)*0.9)
train_size
# Out:
# 998

# %%
df1 = df1.iloc[::-1]

# %%
df1.head()
# Out:
#             APC
# date
# 2022-02-25  516
# 2022-02-26  706
# 2022-02-27  706
# 2022-02-28  816
# 2022-03-01  846

# %%
train,test = df1[:train_size], df1[train_size:]

# %%
model = ARIMA(train["APC"], order=(5,1,0))
# Out:
# c:\Users\Techer314\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\Techer314\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\Techer314\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
model_fit = model.fit()

# %%
forecast = model_fit.forecast(steps=len(test))
test["forecast"] = forecast
# Out:
# C:\Users\Techer314\AppData\Local\Temp\ipykernel_10720\277756396.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["forecast"] = forecast

# %%
test.head()
# Out:
#               APC      forecast
# date
# 2024-11-19  19092  19092.253522
# 2024-11-20  19119  19121.184901
# 2024-11-21  19143  19150.307955
# 2024-11-22  19156  19179.282398
# 2024-11-23  19192  19209.773193

# %%
print(forecast)
# Out:
# 2024-11-19    19092.253522
# 2024-11-20    19121.184901
# 2024-11-21    19150.307955
# 2024-11-22    19179.282398
# 2024-11-23    19209.773193
#                   ...
# 2025-03-05    20823.939769
# 2025-03-06    20831.240161
# 2025-03-07    20838.442581
# 2025-03-08    20845.548344
# 2025-03-09    20852.558747
# Freq: D, Name: predicted_mean, Length: 111, dtype: float64

# %%
test.head()
# Out:
#               APC      forecast
# date
# 2024-11-19  19092  19092.253522
# 2024-11-20  19119  19121.184901
# 2024-11-21  19143  19150.307955
# 2024-11-22  19156  19179.282398
# 2024-11-23  19192  19209.773193

# %%
plt.figure(figsize=(12,5))
plt.plot(train["APC"], label = "Тренувальні дані")
plt.plot(test["APC"], label = "Тестувальні дані")
plt.plot(test["forecast"], label = "Модельний прогноз")
plt.legend()
plt.show()
