# %% [markdown]
# # **Розширений план-контент практичного заняття**
# ## **Тема 4. Заняття 3. Основи проектування сервісів**
# ### **1. Побудова діаграми класів**
# ### **2. Побудова діаграми процесу роботи сервісу**
# 👨‍💻 **Самостійна робота:** Створення проекту сервісу (документування + PlantUML)
#
# ---
#
# ## **1. Вступ (10 хв)**
#
# ### **1.1. Мета заняття**
# - Ознайомити слухачів з основами проектування ІТ-сервісів.
# - Навчити створювати UML-діаграми, які є ключовими в технічній документації сервісів.
# - Закріпити навички моделювання логіки роботи сервісів через самостійну проектну роботу.
#
# ### **1.2. Очікувані результати**
# Після заняття слухачі зможуть:
# ✅ Створювати **діаграми класів** для опису структури сервісу.
# ✅ Проєктувати **процес роботи сервісу** за допомогою **діаграм активності або послідовності**.
# ✅ Розробляти **базову концепцію сервісу** (назва, функції, логіка роботи).
# ✅ Документувати структуру сервісу у вигляді *.puml або *.pdf-файлу.
#
# ---
#
# ## **2. Побудова діаграми класів (30 хв)**
#
# ### **2.1. Призначення діаграми класів**
# 📌 Діаграма класів дозволяє моделювати **структуру об’єктів**, їх атрибути, зв’язки та методи.
# Вона використовується на етапі **архітектурного проектування сервісу**.
#
# 🔹 **Основні компоненти діаграми класів:**
# - **Клас:** назва, поля, методи.
# - **Асоціація:** зв'язок між класами.
# - **Успадкування / реалізація:** спадкоємці інтерфейсів чи базових класів.
#
# ---
#
# ### **2.2. Приклад діаграми класів у PlantUML**
# ```plantuml
# @startuml
# class User {
#   - id: int
#   - name: string
#   - email: string
#   + register(): void
#   + login(): boolean
# }
#
# class AuthService {
#   + authenticate(email: string, password: string): boolean
# }
#
# User --> AuthService : uses
# @enduml
# ```
#
# 📌 **Очікуваний результат:** графічна діаграма зі структурою сервісу автентифікації.
#
# ---
#
# ## **3. Побудова діаграми процесу роботи сервісу (30 хв)**
#
# ### **3.1. Види діаграм**
# 🔸 **Діаграма активності (Activity Diagram)** — модель логіки бізнес-процесу.
# 🔸 **Діаграма послідовності (Sequence Diagram)** — показує взаємодію об'єктів у часі.
#
# ---
#
# ### **3.2. Приклад діаграми активності у PlantUML**
# ```plantuml
# @startuml
# start
# :Отримати запит від користувача;
# :Перевірити авторизацію;
# if (Авторизовано?) then (так)
#   :Обробити запит;
#   :Надіслати відповідь;
# else (ні)
#   :Повернути помилку 403;
# endif
# stop
# @enduml
# ```
#
# ---
#
# ### **3.3. Приклад діаграми послідовності**
# ```plantuml
# @startuml
# actor User
# participant Frontend
# participant Backend
# participant Database
#
# User -> Frontend : Login request
# Frontend -> Backend : API /auth
# Backend -> Database : SELECT * FROM users
# Database --> Backend : User data
# Backend --> Frontend : Token
# Frontend --> User : Token saved
# @enduml
# ```
#
# 📌 **Ці діаграми використовуються для документування логіки сервісу, визначення точок інтеграції.**
#
# ---
#
# ## **4. Самостійна робота: Створення проекту сервісу (30 хв)**
#
# ### **Завдання для студентів**
# 🛠 **Створити концепцію власного ІТ-сервісу**, що виконує одну з функцій (наприклад: реєстрація користувача, збір повідомлень, генерація звітів тощо).
#
# ### **Необхідно реалізувати:**
# 1. Назву та короткий опис сервісу.
# 2. **Діаграму класів** – з основними сутностями.
# 3. **Діаграму процесу роботи** (послідовності або активності).
# 4. Зберегти у вигляді `.puml` файлів або згенерованого зображення.
#
# 📌 **Рекомендоване середовище:**
# - Онлайн: [PlantUML Live](https://www.plantuml.com/plantuml/)
# - VS Code з розширенням "PlantUML"
#
# ---
#
# ## **5. Підсумки заняття (10 хв)**
#
# ✅ **Підсумки:**
# - UML-діаграми є критично важливими у проектуванні сервісів.
# - Діаграми класів визначають структуру, а діаграми процесу — поведінку сервісу.
# - Уміння створювати ці діаграми — це базовий навик для розробників, архітекторів, аналітиків.
#
# 🚀 **Ключовий меседж:**
# **Моделювання — перший крок до якісної реалізації сервісів у хмарних і військово-аналітичних системах.**
