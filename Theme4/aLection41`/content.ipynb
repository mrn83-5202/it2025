# %% [markdown]
# # **Розширений план-контент лекції**
# ## **Тема 4. Заняття 1. Поняття про хмарні технології та сервіси**
# ### **1. Поняття про хмарні технології**
# ### **2. Поняття про хмарні сервіси**
#
# ---
#
# ## **1. Вступ (10 хв)**
#
# ### **1.1. Мета заняття**
# - Ознайомити слухачів з основними поняттями хмарних технологій та їх перевагами.
# - Розглянути різні типи хмарних сервісів та їх застосування.
# - Пояснити роль хмарних технологій у сучасних інформаційних системах, включаючи військову аналітику та управління.
#
# ### **1.2. Очікувані результати**
# Після заняття слухачі зможуть:
# ✅ Розуміти основні концепції **хмарних технологій** та їхню роль у цифровізації.
# ✅ Визначати **основні моделі розгортання** (Public, Private, Hybrid, Multi-Cloud).
# ✅ Використовувати **типи хмарних сервісів** (IaaS, PaaS, SaaS) у професійній діяльності.
# ✅ Аналізувати **безпекові аспекти** використання хмарних технологій.
#
# ---
#
# ## **2. Поняття про хмарні технології (40 хв)**
#
# ### **2.1. Що таке хмарні технології?**
# 📌 **Хмарні технології** – це модель надання обчислювальних ресурсів через Інтернет.
#
# 🔹 **Основні принципи:**
# ✔ **Доступність:** використання ресурсів без необхідності купівлі фізичного обладнання.
# ✔ **Масштабованість:** можливість збільшення або зменшення ресурсів за потреби.
# ✔ **Оптимізація витрат:** оплата лише за використані ресурси.
#
# ---
#
# ### **2.2. Моделі розгортання хмар**
# 📌 **Типи хмарних середовищ**
#
# | Тип хмари | Опис | Приклад |
# |-----------|------|---------|
# | **Public Cloud** | Загальнодоступна хмара, якою користуються багато клієнтів. | AWS, Google Cloud, Azure |
# | **Private Cloud** | Використовується лише однією організацією. | Хмари урядових та військових структур |
# | **Hybrid Cloud** | Поєднання приватних та публічних хмар. | AWS Outposts, Azure Hybrid Cloud |
# | **Multi-Cloud** | Використання декількох хмарних платформ одночасно. | Поєднання AWS та Google Cloud для різних завдань |
#
# 📌 **Приклад гібридного розгортання:**
# ```
# Військове командування використовує приватну хмару для конфіденційних даних
# та публічну хмару для аналізу загальнодоступної інформації.
# ```
#
# ---
#
# ### **2.3. Основні технології хмарних обчислень**
# 📌 **Технології, що забезпечують роботу хмарних сервісів:**
# 🔹 **Віртуалізація** – поділ фізичних ресурсів на логічні середовища.
# 🔹 **Контейнери (Docker, Kubernetes)** – забезпечують швидке розгортання додатків.
# 🔹 **Мережеві технології (SDN, VPN)** – створюють безпечні канали зв’язку.
# 🔹 **Автоматизація (Terraform, Ansible)** – керує інфраструктурою як кодом (IaC).
#
# 📌 **Приклад коду для створення віртуальної машини в AWS за допомогою Terraform:**
# ```hcl
# resource "aws_instance" "example" {
#   ami           = "ami-123456"
#   instance_type = "t2.micro"
#   tags = {
#     Name = "ExampleInstance"
#   }
# }
# ```
#
# ---
#
# ## **3. Поняття про хмарні сервіси (50 хв)**
#
# ### **3.1. Основні типи хмарних сервісів**
# 📌 **Моделі надання хмарних послуг:**
#
# | Тип | Опис | Приклади |
# |------|------|---------|
# | **IaaS (Infrastructure as a Service)** | Віртуальні сервери, мережі, сховища. | AWS EC2, Google Compute Engine |
# | **PaaS (Platform as a Service)** | Платформи для розробки та розгортання додатків. | Google App Engine, AWS Lambda |
# | **SaaS (Software as a Service)** | Готові додатки, доступні через веб. | Gmail, Microsoft Office 365 |
#
# ---
#
# ### **3.2. Порівняння IaaS, PaaS, SaaS**
#
# 📌 **Основні відмінності між сервісами**
#
# | Характеристика | IaaS | PaaS | SaaS |
# |---------------|------|------|------|
# | Контроль користувача | Високий | Середній | Низький |
# | Гнучкість | Висока | Середня | Низька |
# | Відповідальність за налаштування | Користувач | Частково користувач | Постачальник |
# | Використання | Віртуальні машини, мережі | Платформи розробки | Готові веб-додатки |
#
# ---
#
# ### **3.3. Хмарні сервіси у військовій сфері**
# 📌 **Приклади застосування хмарних сервісів:**
# 🔹 **IaaS:** Аналіз супутникових знімків у AWS GovCloud.
# 🔹 **PaaS:** Розгортання аналітичних моделей на Google Cloud AI.
# 🔹 **SaaS:** Використання захищених комунікаційних платформ для військових (Microsoft Teams, Signal).
#
# 📌 **Приклад створення віртуальної машини на Google Cloud із Python:**
# ```python
# from google.cloud import compute_v1
#
# def create_instance(project, zone, instance_name):
#     instance_client = compute_v1.InstancesClient()
#     instance = compute_v1.Instance()
#     instance.name = instance_name
#     instance.machine_type = f"zones/{zone}/machineTypes/e2-micro"
#
#     # Налаштування диска
#     disk = compute_v1.AttachedDisk()
#     disk.auto_delete = True
#     disk.boot = True
#     instance.disks = [disk]
#
#     # Додавання до мережі
#     network_interface = compute_v1.NetworkInterface()
#     instance.network_interfaces = [network_interface]
#
#     operation = instance_client.insert(project=project, zone=zone, instance_resource=instance)
#     return operation
#
# create_instance("my-project", "us-central1-a", "test-instance")
# ```
#
# 📌 **Що робить цей код?**
# ✔ Створює віртуальну машину в Google Cloud.
# ✔ Використовує API для автоматизації інфраструктури.
#
# ---
#
# ## **4. Практичні завдання (30 хв)**
# ✅ **Завдання 1:** Порівняти Public Cloud та Private Cloud для військових інформаційних систем.
# ✅ **Завдання 2:** Створити та налаштувати віртуальну машину в AWS/GCP.
# ✅ **Завдання 3:** Використати Docker для контейнеризації веб-додатка у хмарному середовищі.
#
# ---
#
# ## **5. Висновки та підсумки заняття (10 хв)**
# ✅ **Основні висновки:**
# - **Хмарні технології забезпечують гнучкість, масштабованість та економію ресурсів.**
# - **Сучасні організації використовують хмарні сервіси для зберігання, обробки та аналізу даних.**
# - **IaaS, PaaS та SaaS дозволяють оптимізувати управління інформаційними системами.**
#
# 🚀 **Ключовий меседж:**
# **Хмарні технології є критичним елементом сучасної цифрової інфраструктури та забезпечують ефективне управління даними в усіх сферах діяльності, включаючи військову аналітику.**
