# %% [markdown]
# Ось приклад **розширеного контенту лекції** для
# **Тема 5. Заняття 1: Поняття про UI/UX. Основи веб-дизайну та веб-програмування**
# (орієнтовно для 90 хвилинного заняття — із теоретичними поясненнями, прикладами та активностями).
#
# ---
#
# ## **1. Поняття про UI/UX (User Interface / User Experience)**
#
# ### 1.1. Визначення понять:
# - **UI (User Interface)** — це інтерфейс користувача, тобто візуальна частина системи, з якою взаємодіє користувач (кнопки, меню, форми, кольори).
# - **UX (User Experience)** — досвід користувача, загальні враження від використання продукту (зручність, логічність, емоційність).
#
# ### 1.2. Різниця між UI та UX:
# | Критерій | UI | UX |
# |----------|----|----|
# | Сфокусовано на | Візуальному дизайні | Поведінці та задоволенні користувача |
# | Приклад | Дизайн кнопки | Наскільки зручно натискати цю кнопку |
# | Інструменти | Figma, Adobe XD | UXMap, Hotjar, опитування |
#
# ### 1.3. Компоненти якісного UI:
# - Чіткість та читабельність
# - Контрастність і кольорова гама
# - Іконографіка і візуальні підказки
#
# ### 1.4. Компоненти якісного UX:
# - Простота і логічність навігації
# - Швидкий доступ до основних функцій
# - Емоційне задоволення користувача
#
# ### 1.5. Приклади доброго й поганого UI/UX
# - **Завдання для обговорення в парах**: переглянути 2-3 скріншоти сайтів/додатків і визначити, які елементи хороші, а які потребують покращення.
#
# ---
#
# ## **2. Основи веб-дизайну та веб-програмування**
#
# ### 2.1. Що таке веб-дизайн?
# - Процес створення зовнішнього вигляду сайту.
# - Врахування принципів композиції, кольору, типографіки, доступності.
#
# #### Основні принципи веб-дизайну:
# - Принцип **візуальної ієрархії**
# - **Сіткова система** (grid)
# - **Мобільна адаптивність** (responsive design)
# - **Мінімалізм і фокус на контенті**
#
# ### 2.2. Основи веб-програмування:
# - Поділ на **frontend** і **backend**
#   - **Frontend** — все, що бачить користувач (HTML, CSS, JavaScript)
#   - **Backend** — серверна частина (зберігання даних, обробка запитів, напр. Python, PHP, Node.js)
#
# #### Основні технології:
# - **HTML** – структура
# - **CSS** – стиль
# - **JavaScript** – взаємодія
# - **Фреймворки**: Bootstrap, React
#
# ### 2.3. Взаємозв’язок веб-дизайну і веб-програмування:
# - Дизайнер створює макет → верстальник реалізує його за допомогою HTML/CSS
# - UX-дослідник перевіряє зручність → розробник адаптує поведінку
#
# ---
#
# ## **Практична частина (20-30 хвилин)**
#
# ### Варіант 1 (без кодування):
# - **Завдання**: Оберіть будь-який сайт і проаналізуйте його з точки зору UI та UX. Заповніть таблицю:
#
# | Елемент | UI-оцінка | UX-оцінка | Пропозиції |
# |--------|-----------|-----------|------------|
# | Головне меню | 4/5 | 3/5 | Додати підсвічування активного пункту |
#
# ### Варіант 2 (із кодуванням):
# - **HTML/CSS практика**:
#   - Створити просту веб-сторінку з заголовком, кнопкою і формою.
#   - Застосувати базові CSS стилі: кольори, відступи, шрифт.
#
# ---
#
# ## **Підсумки заняття**
# - Визначили поняття UI і UX, відмінності між ними
# - Ознайомились з основними принципами веб-дизайну
# - Розглянули основи веб-програмування (HTML, CSS, JS)
# - Виконали практичну частину для закріплення
#
# ---
#
# ## **Домашнє завдання**
# 1. Обрати два популярні сайти та порівняти їх інтерфейси з точки зору UI/UX.
# 2. Створити просту HTML-сторінку (1-2 блоки + стилі CSS).
# 3. За бажанням: створити макет інтерфейсу у Figma.
#
# ---
#
# Якщо потрібно, можу зробити презентацію до цієї лекції або варіанти інтерактивних тестів. Хочеш?

# %% [markdown]
# Ось **детальні приклади базових скриптів на HTML, CSS та JavaScript**, які можна використати для демонстрації на занятті або дати студентам як практичні завдання:
#
# ---
#
# ## ✅ **1. Простий сайт з кнопкою, що змінює колір фону**
#
# ### 📄 `index.html`
# ```html
# <!DOCTYPE html>
# <html lang="uk">
# <head>
#   <meta charset="UTF-8">
#   <title>Зміна кольору фону</title>
#   <link rel="stylesheet" href="styles.css">
# </head>
# <body>
#   <h1>Натисни кнопку, щоб змінити колір фону</h1>
#   <button onclick="changeBackground()">Змінити колір</button>
#
#   <script src="script.js"></script>
# </body>
# </html>
# ```
#
# ### 🎨 `styles.css`
# ```css
# body {
#   font-family: Arial, sans-serif;
#   text-align: center;
#   padding: 50px;
#   background-color: #f0f0f0;
# }
#
# button {
#   padding: 10px 20px;
#   font-size: 16px;
#   cursor: pointer;
# }
# ```
#
# ### ⚙️ `script.js`
# ```javascript
# function changeBackground() {
#   const colors = ["#FFD700", "#FF69B4", "#90EE90", "#87CEEB", "#D3D3D3"];
#   const randomColor = colors[Math.floor(Math.random() * colors.length)];
#   document.body.style.backgroundColor = randomColor;
# }
# ```
#
# ---
#
# ## ✅ **2. Форма з валідацією (перевірка імені та email)**
#
# ### 📄 `index.html`
# ```html
# <!DOCTYPE html>
# <html lang="uk">
# <head>
#   <meta charset="UTF-8">
#   <title>Форма з валідацією</title>
#   <link rel="stylesheet" href="form.css">
# </head>
# <body>
#   <h2>Форма реєстрації</h2>
#   <form onsubmit="return validateForm()">
#     <input type="text" id="name" placeholder="Ім’я"><br><br>
#     <input type="email" id="email" placeholder="Email"><br><br>
#     <button type="submit">Надіслати</button>
#   </form>
#   <p id="error" style="color:red;"></p>
#
#   <script src="form.js"></script>
# </body>
# </html>
# ```
#
# ### 🎨 `form.css`
# ```css
# body {
#   font-family: Verdana;
#   text-align: center;
#   padding: 40px;
# }
#
# input {
#   padding: 10px;
#   width: 200px;
# }
# button {
#   padding: 10px 20px;
#   margin-top: 10px;
# }
# ```
#
# ### ⚙️ `form.js`
# ```javascript
# function validateForm() {
#   const name = document.getElementById("name").value.trim();
#   const email = document.getElementById("email").value.trim();
#   const error = document.getElementById("error");
#
#   if (name === "" || email === "") {
#     error.textContent = "Будь ласка, заповніть усі поля.";
#     return false;
#   }
#
#   if (!email.includes("@") || !email.includes(".")) {
#     error.textContent = "Введіть правильний email.";
#     return false;
#   }
#
#   alert("Форма успішно надіслана!");
#   return true;
# }
# ```
#
# ---
#
# ## ✅ **3. Інтерактивна галерея (зображення змінюються по кліку)**
#
# ### 📄 `index.html`
# ```html
# <!DOCTYPE html>
# <html lang="uk">
# <head>
#   <meta charset="UTF-8">
#   <title>Галерея</title>
#   <link rel="stylesheet" href="gallery.css">
# </head>
# <body>
#   <h2>Натисни на зображення для зміни</h2>
#   <img id="galleryImage" src="img1.jpg" width="300" onclick="changeImage()">
#   <script src="gallery.js"></script>
# </body>
# </html>
# ```
#
# ### 🎨 `gallery.css`
# ```css
# body {
#   text-align: center;
#   padding: 40px;
# }
# img {
#   border: 2px solid #333;
#   cursor: pointer;
# }
# ```
#
# ### ⚙️ `gallery.js`
# ```javascript
# let images = ["img1.jpg", "img2.jpg", "img3.jpg"];
# let index = 0;
#
# function changeImage() {
#   index = (index + 1) % images.length;
#   document.getElementById("galleryImage").src = images[index];
# }
# ```
#
# > **Примітка**: переконайтесь, що файли зображень `img1.jpg`, `img2.jpg`, `img3.jpg` є в папці проєкту або змініть шляхи на доступні.
#
# ---
#
# Хочеш, щоб я зібрав усе це в один `.zip` архів для демонстрації або створив онлайн-версію через CodePen чи JSFiddle?
